# %% [markdown]
# Covers the fundamentals of python

# %%
print ("hello world")
# Out:
# hello world

# %%
xstring='55'
xstring=int(xstring)
print (type(xstring))
# Out:
# <class 'int'>

# %%
alist=55,6,'str'
print (alist)
print (type(alist))
# Out:
# (55, 6, 'str')
# <class 'tuple'>

# %%
blist=[55,6,'str']
print (blist)
print (type(blist))
# Out:
# [55, 6, 'str']
# <class 'list'>

# %%
blist*2
# Out:
# [55, 6, 'str', 55, 6, 'str']

# %%
blist.append(2)
print (blist)
# Out:
# [55, 6, 'str', 2, 2]

# %%
blist.pop()
print (blist)
# Out:
# [55, 6, 'str', 2]

# %%
array1=[1,2,32,34,[12,11]]
print (array1)
# Out:
# [1, 2, 32, 34, [12, 11]]

# %%
array2=[1,21,23,41,2]
for i in array2:
    if i>10:
        print ("Large")
# Out:
# Large
# Large
# Large

# %%
#list comprehension
sqr=[n**2 for n in range (1,10)]
print (sqr)
# Out:
# [1, 4, 9, 16, 25, 36, 49, 64, 81]
